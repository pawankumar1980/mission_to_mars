# %%
# Imports
import json
import pandas as pd


from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Set up Browser with Splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Visit the Mars NASA news site
url = 'https://redplanetscience.com'
browser.visit(url)
# Optional delay for loading the page
browser.is_element_present_by_css('div.list_text', wait_time=1)
# Out:
# True

# %%
html = browser.html
news_soup = soup(html, 'html.parser')
news_soup
# Out:
# <html><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
# <link href="css/font.css" rel="stylesheet" type="text/css"/>
# <link href="css/app.css" rel="stylesheet" type="text/css"/>
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
# <title>News - Mars Exploration Program</title>
# </head>
# <body>
# <div class="col-md-12">
# <div class="row">
# <nav class="navbar navbar-expand-lg navbar-light fixed-top">
# <div class="container-fluid">
# <a class="navbar-brand" href="#">
# <img src="image/nasa.png" width="80"/><span class="logo">MARS Planet Science</span>
# ...

# %%
#Scrapping the title text for each article
news_titles=news_soup.find_all('div',class_='content_title')

x=1
for title in news_titles:
    print(x,".",title.text)
    x=x+1
# Out:
# 1 . While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus
# 2 . NASA's Perseverance Rover Is Midway to Mars
# 3 . NASA's Briefcase-Size MarCO Satellite Picks Up Honors
# 4 . NASA Engineers Checking InSight's Weather Sensors
# 5 . NASA's New Mars Rover Is Ready for Space Lasers
# 6 . 5 Hidden Gems Are Riding Aboard NASA's Perseverance Rover
# 7 . A New Video Captures the Science of NASA's Perseverance Mars Rover
# 8 . NASA's Perseverance Rover Goes Through Trials by Fire, Ice, Light and Sound
# 9 . NASA's Mars Reconnaissance Orbiter Undergoes Memory Update
# 10 . NASA's Mars Perseverance Rover Passes Flight Readiness Review
# 11 . Mars 2020 Stands on Its Own Six Wheels
# 12 . NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
# 13 . Screening Soon: 'The Pathfinders' Trains Lens on Mars
# 14 . NASA's Perseverance Rover Attached to Atlas V Rocket
# 15 . NASA's Curiosity Mars Rover Snaps Its Highest-Resolution Panorama Yet

# %%
#Scrapping the Summary text for each article
news_summaries =news_soup.find_all('div', class_ ='article_teaser_body')

y=1
for summary in news_summaries:
    print(y,".",summary.text)
    y=y+1
# Out:
# 1 . This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars.
# 2 . Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination.
# 3 . The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.
# 4 . An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.
# 5 . Perseverance is one of a few Mars spacecraft carrying laser retroreflectors. The devices could provide new science and safer Mars landings in the future.
# 6 . The symbols, mottos, and small objects added to the agency's newest Mars rover serve a variety of purposes, from functional to decorative.
# 7 . With a targeted launch date of July 30, the next robotic scientist NASA is sending to the to the Red Planet has big ambitions.
# ...

# %%
# Slide_elem is the parent element that holds all the elements within it
slide_elem = news_soup.find_all('div',class_='list_text')

# Itereate through all the element to scrap the titles and the summary for each article
mars_list = []
for elem in slide_elem:
    mars_data={"title":"","preview":""}
    title_elem=elem.find('div',class_='content_title')
    title = title_elem.get_text()
    summary_elem= elem.find('div', class_='article_teaser_body')
    summary=summary_elem.get_text()
    mars_data["title"] = title
    mars_data["preview"] = summary
    mars_list.append(mars_data)
print(mars_list)
# Out:
# [{'title': "While Stargazing on Mars, NASA's Curiosity Rover Spots Earth and Venus", 'preview': "This new portrait of the Red Planet's neighbors was taken during a time when there's more dust in the air on Mars."}, {'title': "NASA's Perseverance Rover Is Midway to Mars ", 'preview': "Sometimes half measures can be a good thing – especially on a journey this long. The agency's latest rover only has about 146 million miles left to reach its destination."}, {'title': "NASA's Briefcase-Size MarCO Satellite Picks Up Honors", 'preview': 'The twin spacecraft, the first of their kind to fly into deep space, earn a Laureate from Aviation Week & Space Technology.'}, {'title': "NASA Engineers Checking InSight's Weather Sensors", 'preview': 'An electronics issue is suspected to be preventing the sensors from sharing their data about Mars weather with the spacecraft.'}, {'title': "NASA's New Mars Rover Is Ready for Space Lasers", 'preview': 'Perseverance is one of a few Mars spacecraft carrying l
# ...

# %%
# Export Python list to JSON file
json_mars = json.dumps(mars_list)
print(json_mars)
# Out:
# [{"title": "NASA's MAVEN Observes Martian Night Sky Pulsing in Ultraviolet Light", "preview": "Vast areas of the Martian night sky pulse in ultraviolet light, according to images from NASA\u2019s MAVEN spacecraft. The results are being used to illuminate complex circulation patterns in the Martian atmosphere."}, {"title": "Two Rovers to Roll on Mars Again: Curiosity and Mars 2020", "preview": "They look like twins. But under the hood, the rover currently exploring the Red Planet and the one launching there this summer have distinct science tools and roles to play."}, {"title": "NASA to Hold Mars 2020 Perseverance Rover Launch Briefing", "preview": "Learn more about the agency's next Red Planet mission during a live event on June 17."}, {"title": "NASA's Perseverance Mars Rover Gets Balanced", "preview": "The mission team performed a crucial weight-balancing test on the rover in preparation for this summer's history-making launch to the Red Planet."}, {"title": "NASA's Curiosity Rover
# ...

# %%
# Save json as csv file
df=pd.read_json(json_mars)
df.to_csv('mars.csv',index=False)

# %%
# Quit browser 
browser.quit()
